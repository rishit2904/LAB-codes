# %%
from matplotlib import pyplot as plt
from scipy.sparse import csr_matrix
import numpy as np
import pandas as pd

# %%
x = [5, 2, 9, 4, 7]
y = [10, 5, 8, 4, 2]
plt.plot(x,y)
plt.show()

# %%
arr = np.array([[0, 0, 0], [0, 0, 1], [1, 0, 2]])
print(csr_matrix(arr).tocsc())
# Out:
#   (2, 0)	1
#   (1, 2)	1
#   (2, 2)	2

# %%
x = np.random.normal(170, 10, 10)
print(x)
plt.hist(x)
plt.show()
# Out:
# [161.16605283 159.45896384 173.74258822 161.35353003 172.83028032
#  162.85689877 153.7071127  174.66558118 185.44857022 172.28951254]

# %%
mydataset = { 'cars': ["BMW", "Volvo", "Ford"],'passings': [3, 7, 2] }
myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
new_series= pd.Series([5,6,7,8,9,10])
print(new_series)
# Out:
# 0     5
# 1     6
# 2     7
# 3     8
# 4     9
# 5    10
# dtype: int64

# %%
new_series= pd.Series([5,6,7,8,9,10], index=['a','b','c','d','e','f'])
print(new_series)
print('____________')
print(new_series[['a','b','f']] ==0 ) 
print(new_series['f'])
# Out:
# a     5
# b     6
# c     7
# d     8
# e     9
# f    10
# dtype: int64
# ____________
# a    False
# b    False
# f    False
# dtype: bool
# 10

# %%
df=pd.DataFrame({'Country': ['Kazakhstan','Russia','Belarus','Ukraine'],
                 'Population': [17.04 , 143.5 , 9.5 , 45.5],
                 'Square':[2724902, 17125191,207600,603628]
                },index = ['KZ','RU','BY','UA'])

df.index.name = 'Country Code'
print(df)
# Out:
#                  Country  Population    Square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600
# UA               Ukraine       45.50    603628

# %%
print(df.loc['KZ'])
# Out:
# Country       Kazakhstan
# Population         17.04
# Square           2724902
# Name: KZ, dtype: object

# %%
print(df.iloc[0])
# Out:
# Country       Kazakhstan
# Population         17.04
# Square           2724902
# Name: KZ, dtype: object

# %%
print(df.loc[['KZ','RU'],'Population'])
# Out:
# Country Code
# KZ     17.04
# RU    143.50
# Name: Population, dtype: float64

# %%
df = pd.read_csv('company_sales_data.csv')
df.plot()
plt.show()
